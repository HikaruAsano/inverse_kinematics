# %%
# %load_ext autoreload
# %autoreload 2
from mpl_toolkits.mplot3d import Axes3D 
import numpy as np

# %%
from ik.arm import Arm
import matplotlib.pyplot as plt

# %%
arm=Arm()

# %%
arm.set_angles([0,30,30,30,10])
arm.cord
# Out:
# 30
# 125
#
# 30
# 125
# 60
# 125
#
# 30
# 125
# 60
# 125
# 90
# 82
#
# 30
# 125
# 60
# 125
# 90
# 82
# 100
# 20
#
#
# 88888888
# 167.28021191971624
# 272.44933053329896
# 100
# 10
# array([[  0.        ,  77.        ,   0.        ],
#        [108.25317547, 139.5       ,   0.        ],
#        [170.75317547, 247.75317547,   0.        ],
#        [170.75317547, 329.75317547,   0.        ],
#        [167.28021192, 349.44933053,   0.        ],
#        [167.28021192, 349.44933053,  52.        ],
#        [285.45714228, 370.28711185,  52.        ]])

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
ax.grid()
line,=ax.plot([],[],'o-',lw=3)
# linepath,=ax.plot([],[])
# linepath1,=ax.plot([],[])
# linepath2,=ax.plot([],[])
# linepath3,=ax.plot([],[])

# %%
def init():
    line.set_data([],[])
    # linepath.set_data([],[])
    # linepath1.set_data([],[])
    # linepath2.set_data([],[])
    # linepath3.set_data([],[])
    
    return line #,linepath,linepath1,linepath2


'''
def animate(i):
    thisx=[0,position[i,0,0],position[i,1,0],position[i,2,0],position[i,3,0]] 
    thisy=[0,position[i,0,1],position[i,1,1],position[i,2,1],position[i,3,1]] 
    line.set_data(thisx,thisy)

    linepath.set_data(position[:i,3,0],position[:i,3,1])
    linepath1.set_data(position[:i,2,0],position[:i,2,1])
    linepath2.set_data(position[:i,1,0],position[:i,1,1])
    linepath3.set_data(position[:i,0,0],position[:i,0,1])


    return line #,linepath,linepath1,linepath2

    '''
# Out:
# '\ndef animate(i):\n    thisx=[0,position[i,0,0],position[i,1,0],position[i,2,0],position[i,3,0]] \n    thisy=[0,position[i,0,1],position[i,1,1],position[i,2,1],position[i,3,1]] \n    line.set_data(thisx,thisy)\n\n    linepath.set_data(position[:i,3,0],position[:i,3,1])\n    linepath1.set_data(position[:i,2,0],position[:i,2,1])\n    linepath2.set_data(position[:i,1,0],position[:i,1,1])\n    linepath3.set_data(position[:i,0,0],position[:i,0,1])\n\n\n    return line #,linepath,linepath1,linepath2\n\n    '

# %%
arm.cord
# Out:
# array([[  0.        ,  77.        ,   0.        ],
#        [108.25317547, 139.5       ,   0.        ],
#        [170.75317547, 247.75317547,   0.        ],
#        [170.75317547, 329.75317547,   0.        ],
#        [167.28021192, 349.44933053,   0.        ],
#        [167.28021192, 349.44933053,  52.        ],
#        [285.45714228, 370.28711185,  52.        ]])

# %%
#for 2d frmo yokokara
thisx=[0]
thisy=[0]
thisz=[0]
thisx+=arm.cord[:,0].tolist()
thisy+=arm.cord[:,1].tolist()
thisz+=arm.cord[:,2].tolist()

fig=plt.figure()
fig.set_figheight(10)
fig.set_figwidth(10)
ax1=fig.add_subplot(3,1,1)
ax1.plot(thisx,thisy, color="red")
ax2=fig.add_subplot(3,1,2)
ax2.plot(thisx,thisz, color="blue")
ax3=fig.add_subplot(3,1,3,projection='3d')
ax3.plot(thisx,thisz,thisy)
fig.tight_layout()
fig.show()

# g1 = plt.subplot(111)
# g1.plot(thisx,thisz, color="blue")
# g1.set_aspect('equal')

# g2 = plt.subplot(112)
# g2.plot(thisx,thisz, color="blue")
# g2.set_aspect('equal')

# %%
def onclick(event):
    data=event.xdata
    data2=event.ydata

# %%
fig=plt.figure()
ax=fig.add_subplot(111)
ax.plot(thisx,thisy)
cid = fig.canvas.mpl_connect('button_press_event', onclick)
plt.show()
# Out:
# <div id='44526c58-f3f4-48b7-b573-4dc256d369ac'></div>

# %%
thisx=[0]

thisx+=arm.cord[:,0].tolist()
thisz+=arm.cord[:,2].tolist()
g = plt.subplot()
g.plot(thisx,thisy, color="blue")
g.set_aspect('equal')

# %%
thisx=[0]
thisy=[0]
thisz=[0]
thisx+=arm.cord[:,0].tolist()
thisz+=arm.cord[:,1].tolist()
thisy+=arm.cord[:,2].tolist()
fig=plt.figure()
ax=fig.add_subplot(111,projection='3d')
ax.plot(thisx,thisy,thisz)

plt.show()

# %%
arm.set_angles([0,30,30,30,10])
arm.cord
# Out:
# 30
# 125
#
# 30
# 125
# 60
# 125
#
# 30
# 125
# 60
# 125
# 90
# 82
#
# 30
# 125
# 60
# 125
# 90
# 82
# 100
# 20
#
#
# 88888888
# 167.28021191971624
# 272.44933053329896
# 100
# 10
# array([[  0.        ,  77.        ,   0.        ],
#        [108.25317547, 139.5       ,   0.        ],
#        [170.75317547, 247.75317547,   0.        ],
#        [170.75317547, 329.75317547,   0.        ],
#        [167.28021192, 349.44933053,   0.        ],
#        [167.28021192, 349.44933053,  52.        ],
#        [285.45714228, 370.28711185,  52.        ]])

# %%
167.28+arm.l[6]*np.cos(10*np.pi/180)
# Out:
# 285.45693036146497

# %%
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-376-dbd883db58b7> in <module>
# ----> 1 print(data)
#
# NameError: name 'data' is not defined
